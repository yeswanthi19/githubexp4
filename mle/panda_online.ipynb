# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('train.csv')

# %%
# i want to check first 5 rows
df.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
# last 5 value
df.tail(4)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.sample(2) # it will give the random value
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 586          587         0       2       Jarvis, Mr. John Denzil  male  47.0
# 719          720         0       3  Johnson, Mr. Malkolm Joackim  male  33.0
#
#      SibSp  Parch  Ticket    Fare Cabin Embarked
# 586      0      0  237565  15.000   NaN        S
# 719      0      0  347062   7.775   NaN        S

# %%
# how to check the columns
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df['Survived'].unique()
# Out:
# array([0, 1])

# %%
# how many cabin is there
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
# how to check the shape of data
df.shape
# Out:
# (891, 12)

# %%
# data information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# check the null value
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# what is maximum fare
df['Fare'].max()
# Out:
# 512.3292

# %%
#  what is mimimum age
df.Age.min()
# Out:
# 0.42

# %%
df['Age'].min()
# Out:
# 0.42

# %%
# statistical summary
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.describe(include='O')
# Out:
#                        Name   Sex  Ticket Cabin Embarked
# count                   891   891     891   204      889
# unique                  891     2     681   147        3
# top     Dooley, Mr. Patrick  male  347082    G6        S
# freq                      1   577       7     4      644

# %%
# loc
# find out the person's entire details where the age is 80

# %%
df.loc[df['Age']==80]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 630  male  80.0      0      0  27042  30.0   A23        S

# %%
# try to find the location where fare is greater than 30 as well as 
# age is greater than 35
df.loc[(df['Fare'] > 30) & (df['Age'] > 35)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 6              7         0       1
# 13            14         0       3
# 25            26         1       3
# 35            36         0       1
# ..           ...       ...     ...
# 829          830         1       1
# 835          836         1       1
# 856          857         1       1
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 35                      Holverson, Mr. Alexander Oskar    male  42.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# How many female booked the 1st class ticket
df.loc[(df['Pclass']==1) & (df['Sex']=='female')]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 31            32         1       1
# 52            53         1       1
# ..           ...       ...     ...
# 856          857         1       1
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 2 to 32 row
# 1 to 4 columns
#df.iloc[2:33,1:5]

# %%
# 2, 4 , 6, 8 row and
# 1 to 5 column
df.iloc[2:10:2,1:6]
# Out:
#    Survived  Pclass                                               Name  \
# 2         1       3                             Heikkinen, Miss. Laina
# 4         0       3                           Allen, Mr. William Henry
# 6         0       1                            McCarthy, Mr. Timothy J
# 8         1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
#
#       Sex   Age
# 2  female  26.0
# 4    male  35.0
# 6    male  54.0
# 8  female  27.0

# %%
# new col name will be family
# the combination of SibSp  and Parch
df['Family']=df['SibSp']+df['Parch']

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  Family
# 0      0  A/5 21171   7.2500   NaN        S       1
# 1      0   PC 17599  71.2833   C85        C       1

# %%
# Survived , age, Fare
df[['Survived','Age','Fare']]
# Out:
#      Survived   Age     Fare
# 0           0  22.0   7.2500
# 1           1  38.0  71.2833
# 2           1  26.0   7.9250
# 3           1  35.0  53.1000
# 4           0  35.0   8.0500
# ..        ...   ...      ...
# 886         0  27.0  13.0000
# 887         1  19.0  30.0000
# 888         0   NaN  23.4500
# 889         1  26.0  30.0000
# 890         0  32.0   7.7500
#
# [891 rows x 3 columns]

# %%
# using iloc try to find out the age
# where the age is greater than 55
len(df.iloc[np.where(df['Age']>55)])
# Out:
# 40

# %%
# how to sort the data based on pclass
#df.sort_values('Pclass', ascending=True,ignore_index=True)

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
# please sort the data with respect of age
#df.sort_values('Age',ignore_index = True,ascending=False)

# %%
# group by
# based on pclass we will find out what is minimum price
df.groupby(df['Pclass']).min('Fare')
# Out:
#         PassengerId  Survived   Age  SibSp  Parch  Fare  Family
# Pclass
# 1                 2         0  0.92      0      0   0.0       0
# 2                10         0  0.67      0      0   0.0       0
# 3                 1         0  0.42      0      0   0.0       0

# %%
# based on p class try to find out the maximum price
df.groupby(df['Pclass']).max('Fare')
# Out:
#         PassengerId  Survived   Age  SibSp  Parch      Fare  Family
# Pclass
# 1               890         1  80.0      3      4  512.3292       5
# 2               887         1  70.0      3      3   73.5000       5
# 3               891         1  74.0      8      6   69.5500      10

# %%
# based on gender find out maximum price
df.groupby(df['Sex']).max('Fare')
# Out:
#         PassengerId  Survived  Pclass   Age  SibSp  Parch      Fare  Family
# Sex
# female          889         1       3  63.0      8      6  512.3292      10
# male            891         1       3  80.0      8      5  512.3292      10

# %%
df.groupby(df['Sex']).min('Fare')
# Out:
#         PassengerId  Survived  Pclass   Age  SibSp  Parch  Fare  Family
# Sex
# female            2         0       1  0.75      0      0  6.75       0
# male              1         0       1  0.42      0      0  0.00       0

# %%
# based on embarked find out the minimum price
df.groupby(df['Embarked']).min('Fare')
# Out:
#           PassengerId  Survived  Pclass   Age  SibSp  Parch    Fare  Family
# Embarked
# C                   2         0       1  0.42      0      0  4.0125       0
# Q                   6         0       1  2.00      0      0  6.7500       0
# S                   1         0       1  0.67      0      0  0.0000       0

# %%
# embarked
# minimum price
df.groupby(df['Embarked']).agg({'Fare':'min'})
# Out:
#             Fare
# Embarked
# C         4.0125
# Q         6.7500
# S         0.0000

# %%
# based on gender try to find out the how many people survived
df.groupby(df['Sex']).agg({'Survived':'sum'})
# Out:
#         Survived
# Sex
# female       233
# male         109

# %%
df['Age'].isnull().sum()
# Out:
# np.int64(0)

# %%
# i will add 0 
# where the value is nan
df['Age']=df['Age'].fillna(0).astype(int)

# %%
# c-> 1
# Q->2
# S -> 3
mapping={'C':1,'Q':2,'S':3}
df['Embarked']=df['Embarked'].map(mapping)

# %%
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# ...
