# %%
pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.17.0-cp313-cp313-win_amd64.whl.metadata (10 kB)
# Collecting dnspython<3.0.0,>=2.6.1 (from pymongo)
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Downloading pymongo-4.17.0-cp313-cp313-win_amd64.whl (972 kB)
#    ---------------------------------------- 0.0/972.8 kB ? eta -:--:--
#    --------------------- ------------------ 524.3/972.8 kB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 972.8/972.8 kB 3.1 MB/s eta 0:00:00
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
# Installing collected packages: dnspython, pymongo
#
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    -------------------- ------------------- 1/2 [pymongo]
#    -------------------- ------------------- 1/2 [pymongo]
#    -------------------- ------------------- 1/2 [pymongo]
#    -------------------- ------------------- 1/2 [pymongo]
#    -------------------- ------------------- 1/2 [pymongo]
#    -------------------- ------------------- 1/2 [pymongo]
#    -------------------- ------------------- 1/2 [pymongo]
#    -------------------- ------------------- 1/2 [pymongo]
#    -------------------- ------------------- 1/2 [pymongo]
#    -------------------- ------------------- 1/2 [pymongo]
#    -------------------- ------------------- 1/2 [pymongo]
#    -------------------- ------------------- 1/2 [pymongo]
#    -------------------- ------------------- 1/2 [pymongo]
#    -------------------- ------------------- 1/2 [pymongo]
#    -------------------- ------------------- 1/2 [pymongo]
#    ---------------------------------------- 2/2 [pymongo]
#
# Successfully installed dnspython-2.8.0 pymongo-4.17.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from pymongo import MongoClient
# Connect to MongoDB
client = MongoClient("mongodb://localhost:27017/")
# Create database
db = client["student_db"]
# Create collection
collection = db["students"]

# %%
student = {
    "name": "A",
    "age": 22,
    "course": "Data Science"
}
collection.insert_one(student)
print("Document inserted successfully")
# Out:
# Document inserted successfully

# %%
students = [
    {"name": "m", "age": 23, "course": "Python"},
    {"name": "p", "age": 21, "course": "Machine Learning"}
]
collection.insert_many(students)
# Out:
# InsertManyResult([ObjectId('6a380f21f271db953a52756c'), ObjectId('6a380f21f271db953a52756d')], acknowledged=True)

# %%
for doc in collection.find():
    print(doc)
# Out:
# {'_id': ObjectId('6a380f08f271db953a52756b'), 'name': 'Anwesha', 'age': 22, 'course': 'Data Science'}
# {'_id': ObjectId('6a380f21f271db953a52756c'), 'name': 'm', 'age': 23, 'course': 'Python'}
# {'_id': ObjectId('6a380f21f271db953a52756d'), 'name': 'p', 'age': 21, 'course': 'Machine Learning'}

# %%
collection.update_one(
    {"name": "A},
    {"$set": {"age": 23}}
)

print("Document updated")
# Out:
# Document updated

# %%
for doc in collection.find():
    print(doc)
# Out:
# {'_id': ObjectId('6a380f08f271db953a52756b'), 'name': 'Anwesha', 'age': 23, 'course': 'Data Science'}
# {'_id': ObjectId('6a380f21f271db953a52756c'), 'name': 'm', 'age': 23, 'course': 'Python'}
# {'_id': ObjectId('6a380f21f271db953a52756d'), 'name': 'p', 'age': 21, 'course': 'Machine Learning'}

# %%
collection.delete_one({"name": "p"})

print("Document deleted")
# Out:
# Document deleted

# %%
collection.delete_many({})
# Out:
# DeleteResult({'n': 2, 'ok': 1.0}, acknowledged=True)

# %%
for doc in collection.find():
    print(doc)
